# %%
import sys
sys.path.append('./')
from datasets.dataloader import load_cifar10, RotatedDataset, create_clustered_dataset
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from copy import deepcopy

# %%
trainset, testset = load_cifar10()
trainset, rotated_trainset = create_clustered_dataset(deepcopy(trainset), 2, 'rotation')
testset, rotated_testset = create_clustered_dataset(deepcopy(testset), 2, 'rotation')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
normal_trainloader = DataLoader(trainset, batch_size=1, shuffle=False)
rotated_trainloader = DataLoader(rotated_trainset, batch_size=1, shuffle=False)
fig, axs = plt.subplots(3, 2, figsize=(10, 15))

for i, batch in enumerate(normal_trainloader):
    if i == 3:
        break
    normal_img = batch[0].squeeze(0)
    axs[i,0].imshow(normal_img.numpy().transpose(1, 2, 0))
    axs[i,0].set_title(f'Normal Image {i}')

for i, batch in enumerate(rotated_trainloader):
    if i == 3:
        break
    rotated_img = batch[0].squeeze(0)
    axs[i,1].imshow(rotated_img.numpy().transpose(1, 2, 0))
    axs[i,1].set_title(f'Rotated Image {i}')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9607843..0.99215686].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.84313726..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9607843..0.99215686].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.84313726..1.0].
